# %% [markdown]
# <a href="https://colab.research.google.com/github/chosurenderrrr/test/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/chosurenderrrr/test.git
# Out:
# Cloning into 'test'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
# %cd /content/test
# Out:
# /content/test

# %%
# !touch temp.jpynb

# %%
```
githubからパーソナルアクセストークンを取得する
自分のアイコン→Settings → Developer settings → Personal access tokens → Generate new token
名前を設定したら権限を設定する　repo   admin:repo_hook   delete_repoにチェックを入れてGenerate token 
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
git clone やgit pushでpasswordを求められたらトークンを入れる

フォルダを作成する
$ mkdir awesome
$ cd awesome
フォルダをリポジトリ登録する
$ git init
新規ファイルの作成
$ nano hello.html
ごちゃごちゃ書いたら状態を確認(Untracked files　インデックスに登録されていないよと出るはず)
$ git status
ローカルリポジトリに登録する(Changes to be committed:　コミット対象のファイルと表示される)
$ git add hello.html
$ git status
変更した結果をコミットする -mでコメントを追加できる(nothing to commit, working tree clean 全てのファイルがコミット済ということ)
$ git commit -m "add new file"
$ git status
リモートリポジトリの情報を追加する
$ git remote add origin https://github.com/chosurenderrrr/GCP_setup1.git
リモートリポジトリのマスターにローカルリポジトリの内容を保存する(masterはブランチ名　ブランチ名がデフォでmainの時もあるから注意)
$ git push origin master

リモートリポジトリをクローンする
$ git clone https://github.com/chosurenderrrr/GCP_setup1.git
```

# %%
# Out:
# abc def
